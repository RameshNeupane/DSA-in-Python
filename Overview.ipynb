# %%
# Instantiations
# Methods (ie. member function)
# Dot(.) operator
# Accessors: that returns the information about the state but do not change the state
# Mutators or Update methods: that do change the state

# %%
list1 = [3, 5, 2, 4, 3, 6, 9,8,7,10] # Literals
print(list1)
# Out:
# [3, 5, 2, 4, 3, 6, 9, 8, 7, 10]

# %%
list1.sort()

# %%
list1
# Out:
# [2, 3, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
type(list1)
# Out:
# list

# %%
response = "Flower Yellow"
response.lower()
# Out:
# 'flower yellow'

# %%
response.startswith('y')
# Out:
# False

# %%
response
# Out:
# 'Flower Yellow'

# %%
response.lower().startswith('f') #Immediate calculations
print(response)
# Out:
# Flower Yellow

# %%
n = 10

# %%
type(n)
# Out:
# int

# %%
bool(list1)
# Out:
# True

# %%
emlist = []

# %%
bool(emlist)
# Out:
# False

# %%
n=0b111011

# %%
type(n)
# Out:
# int

# %%
print(n)
# Out:
# 59

# %%
s= 100

# %%
hex(s)
# Out:
# '0x64'

# %%
aba = (1, 3, 4, 5)

# %%
type(aba)
# Out:
# tuple

# %%
abc = (1,)

# %%
type(abc)
# Out:
# tuple

# %%
set1 = set((1, 2, 3,4 ,6,5,7,4,3,7))

# %%
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1.
# Out:
#   File "<ipython-input-26-2ce7ae5b01fe>", line 1
#     set1.
#          ^
# SyntaxError: invalid syntax

# %%
set2 = set((2,5, 4, 6, 3))

# %%
set1.difference(set2)

# %%
set1

# %%
set1.difference_update(set2)

# %%
set1

# %%
set1.difference_update(set2)

# %%
set1

# %%
set1.difference_update(set1)

# %%
set1

# %%
set2

# %%
set2 = str(set2)

# %%
set2

# %%
set1.add(set2)

# %%
set1

# %%
list1 = [1, 2 ]
list2 = [3, 4]

# %%
list1.append(list2)

# %%
list1

# %%
list1[2][0]

# %%
aba.count(2)

# %%
aba.index(5)

# %%
aba.index(2)

# %%
seta = frozenset((1, 2, 3))

# %%
seta

# %%
person = {
    'name': ["Ramesh", "Jayaram"],
    'address': "kalanki",
    'level': "csit"
}

# %%
person['name'][1]

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def display(self):
        print(f"name: {self.name}")
        print(f"age: {self.age}")
        
p1 = Person("Ramesh", 22)
# p1.getname("Ramesh", 21)
p1.display()

# %% [markdown]
# ### Logical Operators

# %%
# not
# and
# or

# %% [markdown]
# ### Equality Operators

# %%
# is: same identity
# is not: different identity
# == : equivalent
# != : not equivalent

# %%
p2 = Person("Ramesh", 21)
p3 = Person("Bipan", 20)

# %%
p1 is p2

# %%
n = 10
m = 10
m is n

# %%
a = 'Ramesh'
b = 'Ramesh'
a is b

# %%
list1

# %%
list1[0:5]

# %%
list1[0:10:2]

# %%
5 in list1

# %%
20 in list1

# %%
set1

# %%
set2

# %%
set1|set2 # Union

# %%
set1 & set2 # Intersection

# %%
set1 - set2

# %%
set1 ^ set2

# %%
set3  = set((12, 13, 20,7))

# %%
set1 ^ set3

# %%
a = 5

# %%
a += 10

# %%
a

# %%
alpha = [1, 2, 3]
beta = alpha

# %%
beta

# %%
beta += [4, 5]

# %%
beta

# %%
beta = beta + [6, 7]

# %%
beta

# %%
alpha = set(alpha)

# %%
alpha is beta

# %%
if not isinstance(alpha, list):
    raise TypeError("alpha must be s set")

# %%
import random

# %%
print(alpha)
random.shuffle(alpha)
print(alpha)

# %%
alpha_1 = random.choice(alpha)
print(alpha_1)

# %%
def is_multiple(n, m):
    if n % m == 0:
        return True
    else:
        return False

# %%
is_multiple(20, 2)

# %%
is_multiple(12, 5)

# %%
def minmax(seq):
    min_num = seq[0]
    max_num = seq[0]
    for i in range(1, len(seq)):
        if seq[i] <= min_num:
            min_num = seq[i]
        if seq[i] >= max_num:
            max_num = seq[i]
    new_seq = (min_num, max_num)
    return new_seq

data_seq = [1, 2, 4, 6, 3, 8, 9]
new_seq = minmax(data_seq)
print(new_seq)

# %%
def sum_of_squares(n):
    sum_odd = 0
    for i in range(1, n):
        if i % 2 != 0:
            sum_odd = sum_odd + i*i
            print(sum_odd)
    return sum_odd

n = 10
print(sum_of_squares(n))

# %%
for i in range(50, 81, 10):
    print(i)

# %%
for i in range(8, -9, -2):
    print(i)

# %%
l = []
e = 1
l.append(e)
for i in range(8):
    e = e * 2
    l.append(e)
print(l)

# %%
l

# %%
import random
a =  random.randrange(0, len(l))
print(l[a])

# %%
l1 = l[ :  : -1] # reverse the list

# %%
l1

# %%
def distinct_pair(seq):
    new_seq = []
    for i in range(len(seq)):
        for j in range(i + 1, len(seq)):
            if seq[i] * seq[j] % 2 != 0:
                e = [seq[i], seq[j]]
                new_seq.append(e)
    return new_seq

ln = [1, 2, 3, 4, 5, 6, 7, 8, 9]
new_seq = distinct_pair(ln)
print(new_seq)

# %%
def diff_num(seq):
    for i in range(len(seq)):
        for j in range(i + 1,  len(seq)):
            if seq[i] == seq[j]:
                return False
    return True

lnum = [1, 2, 3, 4, 7, 6, 8]
re = diff_num(lnum)
print(re)

# %%
list_generated = []
n = int(input("Enter the size of the list: "))
for i in range(n):
    e = i * (i + 1)
    list_generated.append(e)
    
print(list_generated)

# %%
# displays all the alphabets from a - z
alphabet = 'a'
list_alphabet = [alphabet]
while True:
    alphabet = chr(ord(alphabet) + 1)
    list_alphabet.append(alphabet)
    if alphabet == 'z':
        break
print(list_alphabet)

# %%
age = 0 # an initially invalid choice
while age <= 0:
    try: 
        age = int(input( 'Enter your age in years: '))
        if age <= 0:
            print( 'Your age must be positive' )
    except (ValueError, EOFError):
        print( 'Invalid response')

# %%
def make_string(string_list):
    """ It returns the string of data sequence passed in the function.
    
    string_list    Input list of the string eg. ['c', 'a', 't', 'd', 'o', 'g']
    string         Output string after joining the list elements eg. catdog
    """
    string = ''.join(string_list)
    return string

string_list = ['c', 'a', 't','d', 'o', 'g', 's', 'u'] 
""" Input list of the string """

print(f"Input list: {string_list}")
length_string = len(string_list)
word = make_string(string_list) 
""" Converted input list into string ie. catdog """

word_set = set()
""" Output set """

# get_all_possible_string(string_list, word_set)
for i in range(length_string):
    e = string_list.pop(i) 
#     """ Pops out the ith element from the input list."""
        
    new_list = [] 
    """ Temporary list that holds the data before the date is sent to the output set."""

    if i == 0:
        word_set.add(e) 
        """ Initially, is just add the element e into the output set."""
        
    else:
        for word in word_set:
            word_list = list(word)
            len_word_list = len(word_list)
            new_word_list = []

            for new_e  in word_list:
                new_word_list.append(new_e)

            for j in range( len_word_list + 1 ):
                new_word_list.insert(j, e)
                new_word = make_string(new_word_list)
                new_list.append(new_word)
                new_word_list.pop(j)

        word_set.clear() 
        """ Clears the output set to update the output in the set."""
            
        for new_word in new_list:
            word_set.add(new_word)
        """ Add the updated putput in the output set."""
            
    string_list.insert(i, e)
    """ Inserts the popped element into the input string to get the original."""
                
print(f"word_set: {word_set}")
""" Displays all the possible output strings. """
    
count_word = len(word_set)
""" To count all the displayed strings of the output set. """
    
print(f"Total words: {count_word}")
# Out:
# Input list: ['c', 'a', 't', 'd', 'o', 'g', 's', 'u']
# word_set: {'oadcugst', 'gsutdaco', 'dsgotcua', 'dusgacto', 'oscdugta', 'osdcutga', 'utocgdas', 'tuasocgd', 'gctsduoa', 'dgtosauc', 'gudotasc', 'oasdguct', 'tguaosdc', 'goudctas', 'dsgacout', 'cotudsga', 'tgsuacod', 'adcoustg', 'tcasgoud', 'uacdtgos', 'gcoatdsu', 'togucads', 'dsacogtu', 'uaogcdst', 'ugatcsod', 'dgusoatc', 'caduotgs', 'dctauogs', 'studgaoc', 'ocsdagut', 'cagduost', 'sgtcaudo', 'dsoutcga', 'sdatgcou', 'otucagsd', 'saguctdo', 'tgcasoud', 'aocdguts', 'asuogcdt', 'ctsdauog', 'cougsadt', 'tcusaogd', 'douacgst', 'utdsgoac', 'ocusdtga', 'uosgtdac', 'ustcoagd', 'ugdstaco', 'tugcsdoa', 'adgostuc', 'uostcgda', 'cgdtasou', 'uodtcgas', 'aotgsucd', 'dougscat', 'agdctsuo', 'adgtsuoc', 'guoadtcs', 'usdtocag', 'gcatodus', 'gotacsud', 'daugsotc', 'gatuodsc', 'gsoautdc', 'tucdaogs', 'odaucstg', 'tdacusgo', 'stdoucga', 'csgautdo', 'tgocadus', 'oatgdcus', 'suctgaod', 'dstuaogc', 'cgtosdua', 'ctgoadus', 'ducsgoat', 'aodsgctu', 'ctdusoag', 'sgtudcoa', 'acgtsoud', 'udcstoga', 'gsudtoca', 'usoctdag', 'agsdtuco', 'cdutoasg', 'aogucsdt', 'gsudtcao', 'cousagtd', 'tsdcagou', 'sudoctag', 'oudstgac', 'gstoaduc', 'ugodacst', 'gtsodacu', 'uagdsotc', 'otasucdg', 'soutcdga', 'auodctsg', 'sgaocutd', 'csoaudtg', 'aotgsudc', 'goudtacs', 'adotsguc', 'aodgtcsu', 'sctgaoud', 'ctsadoug', 'uotasdcg', 'uodgtsca', 'adguotcs', 'sgdacuot', 'stucgado', 'uadgscot', 'tcdsguoa', 'ucaosgtd', 'agudstco', 'gudcsaot', 'dusocgat', 'doaustgc', 'soadgctu', 'scuogtda', 'tasducog', 'uctadosg', 'tacdguso', 'cgosudta', 'ctosagdu', 'satgdocu', 'gcdsutao', 'odtagcus', 'tocaguds', 'tscadugo', 'udtaogcs', 'gcdautso', 'gtacdsuo', 'odgtcaus', 'odcutags', 'utosgdca', 'cdtausog', 'ouagdcst', 'odsctagu', 'tascogdu', 'udtgcsao', 'dsoagtcu', 'gutocsda', 'gdocusat', 'adcugsto', 'gdatsuco', 'cougsatd', 'uotsdacg', 'dtgscoua', 'toscaudg', 'uacgotsd', 'ogutcsda', 'catosdgu', 'ogstudca', 'tuocgdas', 'ogdtsauc', 'acsdugto', 'gaoducts', 'gtasoudc', 'doatcsgu', 'utdgscoa', 'tugscoad', 'asduoctg', 'sucaotgd', 'toadcgus', 'cgsoaudt', 'dcagoust', 'uocastgd', 'sdtcauog', 'oscuagdt', 'gosdctua', 'ustcgaod', 'casogudt', 'codastug', 'atsucgod', 'aogctsdu', 'gdoctasu', 'odtscaug', 'ogucatds', 'gtdasuoc', 'tguadosc', 'ctuagods', 'dcogusat', 'tuscgdoa', 'oacgtuds', 'osadcugt', 'sodtuacg', 'dostugac', 'ucsdtgao', 'tsuoadcg', 'ucagsodt', 'odcgutas', 'gudcotsa', 'uoatsdcg', 'dacusogt', 'dtoaucgs', 'dcogtsau', 'dsatugoc', 'tgcoausd', 'goutadcs', 'cusaotdg', 'staocgud', 'scgdoatu', 'dsoguatc', 'sgtocdau', 'gscdtuao', 'tgcosdua', 'gasudcot', 'odgtausc', 'gdcosaut', 'cudgtaos', 'dascougt', 'adtgscou', 'dtuoacgs', 'aosdctgu', 'tacgudso', 'asdcgtou', 'gscudtoa', 'taducogs', 'tsouadgc', 'tscdouag', 'gdaocuts', 'adcstugo', 'sotcadug', 'cuatgdso', 'ousatcgd', 'astucgod', 'aoutcdsg', 'sguactod', 'goatudsc', 'tudgaosc', 'togscadu', 'agsuodtc', 'cosatdgu', 'udatgcos', 'usgactdo', 'dgocsatu', 'sadcutgo', 'uadctogs', 'cadtogsu', 'usdgacto', 'tagodusc', 'gdtusoac', 'sugaotcd', 'dgucsota', 'cdtgsoau', 'sgdotacu', 'ucdsaotg', 'cgdosuat', 'tdcosgua', 'cuaotsgd', 'saudoctg', 'ctsodagu', 'dasuocgt', 'acostugd', 'tadgcous', 'gudotcsa', 'coustdag', 'douctsag', 'uosatgdc', 'gctosuad', 'tdsgcauo', 'csotduag', 'utgdsaco', 'sgautocd', 'tdsoaguc', 'gdaocsut', 'sdgautoc', 'sdgutcao', 'uscgodta', 'agtdscuo', 'tsgduoca', 'aoctgdus', 'ustcaodg', 'uascotgd', 'asogdutc', 'dusoagtc', 'ugsodatc', 'uctosadg', 'dctgaous', 'acgsduto', 'ucsdtaog', 'cadustog', 'utsgdcoa', 'osadgcut', 'tocadugs', 'oaudgcts', 'dacgstuo', 'adgcosut', 'udagscot', 'uscgtdao', 'sgacutod', 'sucogadt', 'tocdgsua', 'aosucgdt', 'utodacsg', 'tscougda', 'dcoutags', 'casotudg', 'atosugdc', 'cdtgosua', 'udtgscoa', 'cusagdto', 'dacsguot', 'ductoags', 'otasudgc', 'udsatgoc', 'dcgatuos', 'otgcsdua', 'gtocausd', 'tgosdcua', 'sguotcad', 'gctsoaud', 'tugdcsao', 'ogdcstau', 'gsodactu', 'cdtogusa', 'oatdscgu', 'tsdoacgu', 'usgctdoa', 'udtocasg', 'tdgosauc', 'dtgacsuo', 'odaugsct', 'sogdtacu', 'gstoduca', 'gocdsuta', 'oatcsudg', 'utscgoad', 'dscguaot', 'oagdtscu', 'sgoautdc', 'cgtu ...
# Total words: 40320

# %%
nl = []
s = set()
for i in word_set:
#     print(i)
    i_list = list(i)
#     print(i_list)
    for j in range(len(i_list) + 1):
        new_i_list = i_list.copy()
        new_i_list.insert(j, 'd')
        new_word = make_string(new_i_list)
        nl.append(new_word)
print(nl)
for word in nl:
    new_word = word
    s.add(new_word)
    print(new_word)
    
print(s)
s.clear()
s.add('a')
print(f"s: {s}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8474e7c23d49> in <module>
#       1 nl = []
#       2 s = set()
# ----> 3 for i in word_set:
#       4 #     print(i)
#       5     i_list = list(i)
#
# NameError: name 'word_set' is not defined

# %%
print(word_set)
# Out:
# {'cat', 'act', 'tac', 'cta', 'tca', 'atc'}

# %%
a = [1,2]
a.insert(4, 3)
print(a)
# Out:
# [1, 2, 3]

# %%
class SequenceIterator:
    def __init__(self, sequence):
        self._seq = sequence
        self._k = -1
        
    def __next__(self):
        self._k += 1
        if self._k < len(self._seq):
            return self._seq[self._k]
        else:
            raise StopIterator()
            
    def __iter__(self):
        return self
    
s = SequenceIterator([1, 2, 3, 4, 5])

# %%
next(s)
# Out:
# 1

# %%
iter(s)

# %%
print(iter(s))
# Out:
# <__main__.SequenceIterator object at 0x000001DC61050F60>

# %%
r = iter(s)

# %%
r

# %%
next(r)
# Out:
# 2

# %%
next(s)
# Out:
# 3

# %%
next(s)
# Out:
# 4

# %%
next(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-14474bab483f> in <module>
# ----> 1 next(5)
#
# TypeError: 'int' object is not an iterator

# %%
r = range(8, 140, 5)

# %%
r
# Out:
# range(8, 140, 5)

# %% [markdown]
# ## Progression

# %%
class Progression:
    def __init__(self, start = 0):
        self._current = start
        
    def _advance(self):
        self._current += 1
        
    def __next__(self):
        if self._current is None:
            raise StopIteration()
        else:
            answer = self._current
            self._advance()
            return answer
        
    def __iter__(self):
        return self
    
    def print_progression(self, n):
        print(''.join(str(next(self)) for j in range(n)))

# %% [markdown]
# ### Stack Using Python List

# %%
class Error(Exception):
    pass

class ArrayStack:
    def __init__(self):
        self._data = []
        
    def __len__(self):
        return len(self._data)
    
    def is_empty(self):
        return len(self._data) == 0
    
    def push(self, e):
        self._data.append(e)
        
    def pop(self):
        if self.is_empty():
            raise Error("Stack is empty.")
        return self._data.pop()
    
    def top(self):
        if self.is_empty():
            raise Error("Stack is empty.")
        return self._data[-1]
    
    def display_stack(self):
        print(f"Current stack: {self._data}")

# %%
Stack1 = ArrayStack()

# %%
Stack1.top()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-15-7ce811db268e> in <module>
# ----> 1 Stack1.top()
#
# <ipython-input-13-53f2a7fc5813> in top(self)
#      22     def top(self):
#      23         if self.is_empty():
# ---> 24             raise Error("Stack is empty.")
#      25         return self._data[-1]
#      26
#
# Error: Stack is empty.

# %%
Stack1.push(1)
Stack1.push(2)
Stack1.push(3)
Stack1.push(4)

# %%
Stack1.display_stack()
# Out:
# Current stack: [1, 2, 3, 4]

# %%
Stack1.pop()
# Out:
# 4

# %%
Stack1.pop()
# Out:
# 3

# %%
Stack1.pop()
# Out:
# 2

# %%
Stack1.pop()
# Out:
# 1

# %%
Stack1.pop()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-30-368ff06967c5> in <module>
# ----> 1 Stack1.pop()
#
# <ipython-input-13-53f2a7fc5813> in pop(self)
#      17     def pop(self):
#      18         if self.is_empty():
# ---> 19             raise Error("Stack is empty.")
#      20         return self._data.pop()
#      21
#
# Error: Stack is empty.

# %% [markdown]
# ### Queue

# %%
class ArrayQueue:
    DEF_SIZE = 3
    def __init__(self):
        self._data = [None] * DEF_SIZE
        self._size = 0
        self.header = 
    
    def display_queue(self):
        print(f"Current queue: {self._data}")
        
    def is_empty(self):
        return self._size == 0
    
    def enqueue(self, e):
        if self.is_empty():
            self._data[0] = e
            
        elif self._size == 3:
            print("Queue is full.")
        else: 
            new = self._data.copy()
            for i in range(1, self._size + 1):
                self._data[i] = new[i - 1]
            self._data[0] = e
        self._size += 1  
        
    def dequeue(self):
        if is_empty():
            print("Queue is empty.")

# %%
q = ArrayQueue()

# %%
q.enqueue(3)
q.display_queue()
# Out:
# Current queue: [3, None, None]

# %%
q.enqueue(4)
q.display_queue()
# Out:
# Current queue: [4, 3, None]

# %%
q.enqueue(5)
q.display_queue()
# Out:
# Current queue: [5, 4, 3]

# %%
q.enqueue(6)
# Out:
# Queue is full.

# %%
q.display_queue()
# Out:
# Current queue: [5, 4, 3]

# %%
l = [None] * 3

# %%
print(l)
# Out:
# [None, None, None]
